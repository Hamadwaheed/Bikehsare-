San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 28                              Clay St at Battery St             37.795001
# 29  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 30  San Francisco Ferry Building (Harry Bridges Pl...             37.795392
# 31                             Davis St at Jackson St             37.797280
# 32                              Clay St at Battery St             37.795001
# 33                            Addison St at Fourth St             37.866249
# 34                            14th St at Mandela Pkwy             37.810743
# 35                            Market St at Dolores St             37.769305
# 36                     Santa Clara St at Almaden Blvd             37.333988
# 37                      The Embarcadero at Sansome St             37.804770
# 38                      The Embarcadero at Sansome St             37.804770
# 39                                Bay Pl at Vernon St             37.812314
# 40                        Victoria Manalo Draves Park             37.777791
# 41                        Victoria Manalo Draves Park             37.777791
# 42                            Steuart St at Market St             37.794130
# 43                      The Embarcadero at Steuart St             37.791464
# 44                      The Embarcadero at Steuart St             37.791464
# 45                      The Embarcadero at Vallejo St             37.799953
# 46                               Mission Dolores Park             37.761420
# 47                             Valencia St at 24th St             37.752428
# 48                            College Ave at Taft Ave             37.841800
# 49                      The Embarcadero at Sansome St             37.804770
#
#     end_station_longitude  bike_id   user_type
# 0             -122.415929       96    Customer
# 1             -122.426614       88    Customer
# 2             -122.267764     1094    Customer
# 3             -122.408445     2831    Customer
# 4             -122.265896     3167  Subscriber
# 5             -122.395282     1487    Customer
# 6             -122.299371     3539    Customer
# 7             -122.400876     1503    Customer
# 8             -122.399051     3125    Customer
# 9             -122.399051     2543    Customer
# 10            -122.394643     3058    Customer
# 11            -122.394643     3197    Customer
# 12            -122.390428     2311  Subscriber
# 13            -122.390428     3717  Subscriber
# 14            -122.391034     3452    Customer
# 15            -122.391865      558  Subscriber
# 16            -122.391865     3646  Subscriber
# 17            -122.394203     1667    Customer
# 18            -122.394203     3114  Subscriber
# 19            -122.414817     1473  Subscriber
# 20            -121.877120     1603  Subscriber
# 21            -122.403234      809    Customer
# 22            -122.415443     2415  Subscriber
# 23            -122.391034     3671    Customer
# 24            -122.391034     3375    Customer
# 25            -122.391034     2721    Customer
# 26            -122.391034     2522    Customer
# 27            -122.394203      533    Customer
# 28            -122.399970     1456  Subscriber
# 29            -122.394203     1691    Customer
# 30            -122.394203     1568    Customer
# 31            -122.398436     2823    Customer
# 32            -122.399970     1634  Subscriber
# 33            -122.299371     3539    Customer
# 34            -122.291415     3598  Subscriber
# 35            -122.426826     2728  Subscriber
# 36            -121.894902       47  Subscriber
# 37            -122.403234     3329    Customer
# 38            -122.403234      970    Customer
# 39            -122.260779     2674  Subscriber
# 40            -122.406432     1227  Subscriber
# 41            -122.406432     3595  Subscriber
# 42            -122.394430     2828    Customer
# 43            -122.391034     3344    Customer
# 44            -122.391034     1019    Customer
# 45            -122.398525     1717    Customer
# 46            -122.426435     1780    Customer
# 47            -122.420628     3067  Subscriber
# 48            -122.251535     1439  Subscriber
# 49            -122.403234     1691    Customer

# %%
df.info(50)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519700 entries, 0 to 519699
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             519700 non-null  int64
#  1   start_time               519700 non-null  object
#  2   end_time                 519700 non-null  object
#  3   start_station_id         519700 non-null  int64
#  4   start_station_name       519700 non-null  object
#  5   start_station_latitude   519700 non-null  float64
#  6   start_station_longitude  519700 non-null  float64
#  7   end_station_id           519700 non-null  int64
#  8   end_station_name         519700 non-null  object
#  9   end_station_latitude     519700 non-null  float64
#  10  end_station_longitude    519700 non-null  float64
#  11  bike_id                  519700 non-null  int64
#  12  user_type                519700 non-null  object
# dtypes: float64(4), int64(4), object(5)
# memory usage: 51.5+ MB

# %% [markdown]
# ## Cleaning

# %% [markdown]
# #### start_time and end_time are not timestamps

# %% [markdown]
# ### Code

# %%
df_cleaned = df.copy()

# %%
df_cleaned.start_time = pd.to_datetime(df_cleaned.start_time)
df_cleaned.end_time = pd.to_datetime(df_cleaned.end_time)

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519700 entries, 0 to 519699
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             519700 non-null  int64
#  1   start_time               519700 non-null  datetime64[ns]
#  2   end_time                 519700 non-null  datetime64[ns]
#  3   start_station_id         519700 non-null  int64
#  4   start_station_name       519700 non-null  object
#  5   start_station_latitude   519700 non-null  float64
#  6   start_station_longitude  519700 non-null  float64
#  7   end_station_id           519700 non-null  int64
#  8   end_station_name         519700 non-null  object
#  9   end_station_latitude     519700 non-null  float64
#  10  end_station_longitude    519700 non-null  float64
#  11  bike_id                  519700 non-null  int64
#  12  user_type                519700 non-null  object
# dtypes: datetime64[ns](2), float64(4), int64(4), object(3)
# memory usage: 51.5+ MB

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         80110  2017-12-31 16:57:39.6540  2018-01-01 15:12:50.2450
# 1         78800  2017-12-31 15:56:34.8420  2018-01-01 13:49:55.6170
# 2         45768  2017-12-31 22:45:48.4110  2018-01-01 11:28:36.8830
# 3         62172  2017-12-31 17:31:10.6360  2018-01-01 10:47:23.5310
# 4         43603  2017-12-31 14:23:14.0010  2018-01-01 02:29:57.5710
#
#    start_station_id                                 start_station_name  \
# 0                74                              Laguna St at Hayes St
# 1               284  Yerba Buena Center for the Arts (Howard St at ...
# 2               245                             Downtown Berkeley BART
# 3                60                               8th St at Ringold St
# 4               239                      Bancroft Way at Telegraph Ave
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.776435              -122.426244              43
# 1               37.784872              -122.400876              96
# 2               37.870348              -122.267764             245
# 3               37.774520              -122.409449               5
# 4               37.868813              -122.258764             247
#
#                                     end_station_name  end_station_latitude  \
# 0  San Francisco Public Library (Grove St at Hyde...             37.778768
# 1                              Dolores St at 15th St             37.766210
# 2                             Downtown Berkeley BART             37.870348
# 3       Powell St BART Station (Market St at 5th St)             37.783899
# 4                          Fulton St at Bancroft Way             37.867789
#
#    end_station_longitude  bike_id   user_type
# 0            -122.415929       96    Customer
# 1            -122.426614       88    Customer
# 2            -122.267764     1094    Customer
# 3            -122.408445     2831    Customer
# 4            -122.265896     3167  Subscriber

# %%
df_cleaned['start_time_month_name']=df_cleaned['start_time'].dt.strftime('%B')

# %%
df_cleaned['start_time_month']=df_cleaned['start_time'].dt.month.astype(int)

# %%
df_cleaned['start_time_weekday']=df_cleaned['start_time'].dt.strftime('%a')

# %%
df_cleaned['start_time_day']=df_cleaned['start_time'].dt.day.astype(int)

# %%
df_cleaned['start_time_hour']=df_cleaned['start_time'].dt.hour

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 519700 entries, 0 to 519699
# Data columns (total 18 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             519700 non-null  int64
#  1   start_time               519700 non-null  datetime64[ns]
#  2   end_time                 519700 non-null  datetime64[ns]
#  3   start_station_id         519700 non-null  int64
#  4   start_station_name       519700 non-null  object
#  5   start_station_latitude   519700 non-null  float64
#  6   start_station_longitude  519700 non-null  float64
#  7   end_station_id           519700 non-null  int64
#  8   end_station_name         519700 non-null  object
#  9   end_station_latitude     519700 non-null  float64
#  10  end_station_longitude    519700 non-null  float64
#  11  bike_id                  519700 non-null  int64
#  12  user_type                519700 non-null  object
#  13  start_time_month_name    519700 non-null  object
#  14  start_time_month         519700 non-null  int64
#  15  start_time_weekday       519700 non-null  object
#  16  start_time_day           519700 non-null  int64
#  17  start_time_hour          519700 non-null  int64
# dtypes: datetime64[ns](2), float64(4), int64(7), object(5)
# memory usage: 71.4+ MB

# %% [markdown]
# ### What is the structure of your dataset?
#
# > Your answer here!
#
# ### What is/are the main feature(s) of interest in your dataset?
#
# > Your answer here!
#
# ### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
#
# > Your answer here!

# %%
g = sns.catplot(data=df_cleaned, x='start_time_month', kind='count', color = 'black')
g.set_axis_labels("Month", "#Bike Trips")
g.fig.suptitle('Monthly usage of the bike share system', y=1.03, fontsize=14, fontweight='semibold');

# %%
weekday = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
g = sns.catplot(data=df_cleaned, x='start_time_weekday', kind='count', color = base_color, order = weekday)
g.set_axis_labels("Weekdays", "#Bike Trips")
g.fig.suptitle('Weekly usage of the bike share system', y=1.03, fontsize=14, fontweight='semibold');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-e060e7f1b084> in <module>
#       1 weekday = ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun']
# ----> 2 g = sns.catplot(data=df_cleaned, x='start_time_weekday', kind='count', color = base_color, order = weekday)
#       3 g.set_axis_labels("Weekdays", "#Bike Trips")
#       4 g.fig.suptitle('Weekly usage of the bike share system', y=1.03, fontsize=14, fontweight='semibold');
#
# NameError: name 'base_color' is not defined

# %% [markdown]
# ## Univariate Exploration
#
# > In this section, investigate distributions of individual variables. If
# you see unusual points or outliers, take a deeper look to clean things up
# and prepare yourself to look at relationships between variables.

# %% [markdown]
# > Make sure that, after every plot or related series of plots, that you
# include a Markdown cell with comments about what you observed, and what
# you plan on investigating next.

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# > Your answer here!
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# > Your answer here!

# %% [markdown]
# ## Bivariate Exploration
#
# > In this section, investigate relationships between pairs of variables in your
# data. Make sure the variables that you cover here have been introduced in some
# fashion in the previous section (univariate exploration).

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# > Your answer here!
#
# ### Did you observe any interesting relationships between the other features (not the main feature(s) of interest)?
#
# > Your answer here!

# %% [markdown]
# ## Multivariate Exploration
#
# > Create plots of three or more variables to investigate your data even
# further. Make sure that your investigations are justified, and follow from
# your work in the previous sections.

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
#
# > Your answer here!
#
# ### Were there any interesting or surprising interactions between features?
#
# > Your answer here!

# %% [markdown]
# > At the end of your report, make sure that you export the notebook as an
# html file from the `File > Download as... > HTML` menu. Make sure you keep
# track of where the exported file goes, so you can put it in the same folder
# as this notebook for project submission. Also, make sure you remove all of
# the quote-formatted guide notes like this one before you finish your report!
